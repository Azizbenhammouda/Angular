# %% [markdown]
# <a href="https://colab.research.google.com/github/Azizbenhammouda/Angular/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ML")
2+2
# Out:
# ML
# 4

# %%
import pandas as pd
from sklearn.datasets import load_iris
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['species'] = data.target

# Show first 5 rows
print("Our data:")
df.head()
